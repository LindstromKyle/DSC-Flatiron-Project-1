# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
plt.style.use('seaborn')
sns.set_palette("colorblind")

# %matplotlib inline

# %%
genres_breakdown = pd.read_csv('zippedData/genres_breakdown.csv')

# %%
genres_breakdown
# Out:
#                   Genre  Movies  TotalBoxOffice        Tickets   Share
# 0             Adventure    1138    6.554765e+10  9,329,378,488  26.84%
# 1                Action    1141    5.284109e+10  7,293,604,581  21.64%
# 2                 Drama    5562    3.586833e+10  5,448,415,784  14.69%
# 3                Comedy    2456    3.411547e+10  5,201,028,664  13.97%
# 4     Thriller/Suspense    1249    2.008128e+10  2,919,856,638   8.22%
# 5                Horror     752    1.385375e+10  1,973,606,071   5.67%
# 6       Romantic Comedy     646    1.078532e+10  1,734,403,730   4.42%
# 7               Musical     205    4.336669e+09    573,201,366   1.78%
# 8           Documentary    2465    2.526248e+09    376,864,759   1.03%
# 9          Black Comedy     220    2.244064e+09    328,610,541   0.92%
# 10              Western      95    1.292636e+09    187,668,543   0.53%
# 11  Concert/Performance      84    4.202741e+08     56,637,807   0.17%
# ...
