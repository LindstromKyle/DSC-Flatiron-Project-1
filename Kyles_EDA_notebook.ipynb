# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect('zippedData/im.db')
#Test_pull6

# %%
tn_movie_budgets = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
tn_movie_budgets
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
tmbd_movies = pd.read_csv('zippedData/tmdb.movies.csv.gz')
tmbd_movies
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
rt_reviews = pd.read_csv('zippedData/rt.reviews.tsv.gz', delimiter = '\t', encoding = 'unicode_escape')
rt_reviews
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
# ...

# %%
rt_movie_info = pd.read_csv('zippedData/rt.movie_info.tsv.gz', delimiter = '\t', encoding = 'unicode_escape')
rt_movie_info
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# ...

# %%
bom_movie_gross = pd.read_csv('zippedData/bom.movie_gross.csv.gz')
bom_movie_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %% [markdown]
# # BEGIN SQL DATABASE SECTION
#
#
#
#
#
#
#
#
# Here

# %%
pd.read_sql("""
SELECT name FROM sqlite_master
WHERE type = 'table'
;
""",conn)
# Out:
#             name
# 0   movie_basics
# 1      directors
# 2      known_for
# 3     movie_akas
# 4  movie_ratings
# 5        persons
# 6     principals
# 7        writers

# %%
pd.read_sql("""
SELECT *
FROM movie_basics
;
""",conn)
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
pd.read_sql("""
SELECT *
FROM directors
;
""",conn)
# Out:
#          movie_id   person_id
# 0       tt0285252   nm0899854
# 1       tt0462036   nm1940585
# 2       tt0835418   nm0151540
# 3       tt0835418   nm0151540
# 4       tt0878654   nm0089502
# ...           ...         ...
# 291169  tt8999974  nm10122357
# 291170  tt9001390   nm6711477
# 291171  tt9001494  nm10123242
# 291172  tt9001494  nm10123248
# 291173  tt9004986   nm4993825
#
# [291174 rows x 2 columns]

# %%
pd.read_sql("""
SELECT *
FROM known_for
;
""",conn)
# Out:
#          person_id   movie_id
# 0        nm0061671  tt0837562
# 1        nm0061671  tt2398241
# 2        nm0061671  tt0844471
# 3        nm0061671  tt0118553
# 4        nm0061865  tt0896534
# ...            ...        ...
# 1638255  nm9990690  tt9090932
# 1638256  nm9990690  tt8737130
# 1638257  nm9991320  tt8734436
# 1638258  nm9991320  tt9615610
# 1638259  nm9993380  tt8743182
#
# [1638260 rows x 2 columns]

# %%
pd.read_sql("""
SELECT *
FROM movie_akas
;
""",conn)
# Out:
#          movie_id  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru   None
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención   None
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
# ...

# %%
pd.read_sql("""
SELECT *
FROM movie_ratings
;
""",conn)
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
pd.read_sql("""
SELECT *
FROM persons
;
""",conn)
# Out:
#         person_id         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# ...

# %%
pd.read_sql("""
SELECT *
FROM principals
;
""",conn)
# Out:
#           movie_id  ordering   person_id  category       job  \
# 0        tt0111414         1   nm0246005     actor      None
# 1        tt0111414         2   nm0398271  director      None
# 2        tt0111414         3   nm3739909  producer  producer
# 3        tt0323808        10   nm0059247    editor      None
# 4        tt0323808         1   nm3579312   actress      None
# ...            ...       ...         ...       ...       ...
# 1028181  tt9692684         1   nm0186469     actor      None
# 1028182  tt9692684         2   nm4929530      self      None
# 1028183  tt9692684         3  nm10441594  director      None
# 1028184  tt9692684         4   nm6009913    writer    writer
# 1028185  tt9692684         5  nm10441595  producer  producer
#
#                    characters
# 0                 ["The Man"]
# 1                        None
# 2                        None
# 3                        None
# 4            ["Beth Boothby"]
# ...                       ...
# ...

# %%
pd.read_sql("""
SELECT *
FROM writers
;
""",conn)
# Out:
#          movie_id   person_id
# 0       tt0285252   nm0899854
# 1       tt0438973   nm0175726
# 2       tt0438973   nm1802864
# 3       tt0462036   nm1940585
# 4       tt0835418   nm0310087
# ...           ...         ...
# 255868  tt8999892  nm10122246
# 255869  tt8999974  nm10122357
# 255870  tt9001390   nm6711477
# 255871  tt9004986   nm4993825
# 255872  tt9010172   nm8352242
#
# [255873 rows x 2 columns]

# %%
test_df = pd.read_sql("""
SELECT *
FROM movie_basics
JOIN directors
    USING(movie_id)
JOIN movie_ratings
    USING(movie_id)
JOIN persons
    USING(person_id)
JOIN principals
    USING(movie_id)
WHERE principals.category = 'actor' OR principals.category = 'actress'
;
""",conn)

# %%
test_df.duplicated().sum()
# Out:
# 345396

# %%
test_df2 = test_df.drop_duplicates(subset = ['primary_name']).sort_values(by = 'start_year', ascending = False)
test_df2
# Out:
#           movie_id                    primary_title  \
# 627923   tt9681728                  A Russian Youth
# 603996   tt8949056                    Yes, God, Yes
# 305791   tt4241904               The Way We Weren't
# 306033   tt4300924                   My Name Is Now
# 47258   tt10011508      Trixie Mattel: Moving Parts
# ...            ...                              ...
# 40327    tt1666555                      Anchor Baby
# 316164   tt3514810                        Follow Me
# 40342    tt1693693                   Istri bo'ongan
# 40350    tt1696198                 Zombie Driftwood
# 139952   tt1764270  Die verrückte Welt der Ute Bock
#
#                          original_title  start_year  runtime_minutes  \
# 627923                  Malchik russkiy        2019             72.0
# 603996                    Yes, God, Yes        2019             78.0
# 305791               The Way We Weren't        2019             93.0
# ...

# %%
test_df3 = test_df2.merge(tn_movie_budgets, left_on='primary_title', right_on = 'movie' , how='inner').sort_values(by = 'worldwide_gross', ascending = False)
test_df3
# Out:
#        movie_id              primary_title                original_title  \
# 1081  tt2121250                      Alpha                         Alpha
# 1347  tt2261633                     Hitman                        Hitman
# 594   tt1355683                 Black Mass                    Black Mass
# 174   tt8043306           Teefa in Trouble              Teefa in Trouble
# 1636  tt1605776                  The Visit                     The Visit
# ...         ...                        ...                           ...
# 1018  tt2091427             Treading Water  The Boy Who Smells Like Fish
# 863   tt1681370               The Algerian                  The Algerian
# 1287  tt1989646        Theresa Is a Mother           Theresa Is a Mother
# 1574  tt1568341  Some Guy Who Kills People     Some Guy Who Kills People
# 404   tt2237914              Aztec Warrior                 Aztec Warrior
#
#       start_year  runtime_minutes                   genres  person_id  \
# ...

# %% [markdown]
# # Join tn_movie_budgets and tmbd_movies

# %%
#tmbd_movies['original_title'] = tmbd_movies['original_title'].str.replace('â\x80\x99', '')

csv_merge_1_2 = tn_movie_budgets.merge(tmbd_movies, left_on='movie', right_on = 'original_title' , how='left')

csv_merge_1_2['worldwide_gross'] = csv_merge_1_2['worldwide_gross'].str.replace(',','').str.replace('$','').apply(lambda x: int(x))

# %%
csv_merge_1_2.sort_values(by = 'worldwide_gross', ascending = False)
# Out:
#       id_x release_date_x                                 movie  \
# 0        1   Dec 18, 2009                                Avatar
# 46      43   Dec 19, 1997                               Titanic
# 5        6   Dec 18, 2015  Star Wars Ep. VII: The Force Awakens
# 6        7   Apr 27, 2018                Avengers: Infinity War
# 35      34   Jun 12, 2015                        Jurassic World
# ...    ...            ...                                   ...
# 3668    63   Nov 27, 2009                    The Cry of the Owl
# 5499    84    Sep 7, 2012                             Crowsnest
# 5500    85   Sep 14, 2012                              Airborne
# 5501    86    Sep 9, 2014                Cotton Comes to Harlem
# 5374    62    Aug 5, 1955                    The Kingâs Thief
#
#      production_budget domestic_gross  worldwide_gross  Unnamed: 0  \
# 0         $425,000,000   $760,507,625       2776345279         6.0
# ...

# %%
csv_merge_1_2['movie'][5374]
# Out:
# 'The Kingâ\x80\x99s Thief'

# %%
tmbd_movies['original_title'] = tmbd_movies['original_title'].str.replace('â\x80\x99', "'")

# %% [markdown]
# #  MERGE  rt_movie_info with rt_reviews

# %%
rt_reviews['rating'] = rt_reviews.loc[rt_reviews['rating'].str.contains('/5') == True]['rating'].apply(lambda x: int(x[0]) / int(x[-1])  if len(x) == 3 else  float(x[0:2]) / int(x[-1])    )
rt_reviews_nona = rt_reviews.dropna(subset = ['rating'])
rt_reviews_mean = rt_reviews_nona.groupby(['id'])[['rating']].agg(['mean'])*100
rt_reviews_mean
# Out:
#          rating
#            mean
# id
# 3     59.600000
# 5     68.888889
# 6     52.380952
# 8     60.000000
# 10    49.090909
# ...         ...
# 1996  62.222222
# 1997  47.692308
# 1998  60.000000
# 1999  52.500000
# 2000  43.636364
#
# [1054 rows x 1 columns]

# %%
rt_reviews['rating'] = rt_reviews.loc[rt_reviews['rating'].str.contains('/5') == True]['rating'].apply(lambda x: int(x[0]) / int(x[-1])  if len(x) == 3 else  float(x[0:2]) / int(x[-1])    )

# %%
rt_reviews_nona = rt_reviews.dropna(subset = ['rating'])

# %%
#rt_reviews.iloc[50:75]

# %%
rt_reviews_nona
# Out:
#          id                                             review  rating  \
# 0         3  A distinctly gallows take on contemporary fina...     0.6
# 7         3  Cronenberg is not a director to be daunted by ...     0.4
# 15        3  For better or worse - often both - Cosmopolis ...     0.6
# 16        3  For one of the smartest films I've seen in a w...     0.8
# 23        3  Those who said Don DeLillo's book was unfilmab...     0.4
# ...     ...                                                ...     ...
# 54424  2000  Dawdles and drags when it should pop; it doesn...     0.2
# 54428  2000                                                NaN     0.2
# 54429  2000                                                NaN     0.4
# 54430  2000                                                NaN     0.4
# 54431  2000                                                NaN     0.6
#
#         fresh             critic  top_critic           publisher  \
# ...

# %%
rt_reviews_mean = rt_reviews_nona.groupby(['id'])[['rating']].agg(['mean'])*100

# %%
rt_reviews_mean
# Out:
#          rating
#            mean
# id
# 3     59.600000
# 5     68.888889
# 6     52.380952
# 8     60.000000
# 10    49.090909
# ...         ...
# 1996  62.222222
# 1997  47.692308
# 1998  60.000000
# 1999  52.500000
# 2000  43.636364
#
# [1054 rows x 1 columns]

# %%
rt_merged = rt_movie_info.merge(rt_reviews_mean, on = 'id' , how='inner')
rt_merged
# Out:
# /Users/lindstromkyle/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/reshape/merge.py:643: UserWarning: merging between different levels can give an unintended result (1 levels on the left,2 on the right)
#   warnings.warn(msg, UserWarning)
#         id                                           synopsis rating  \
# 0        3  New York City, not-too-distant-future: Eric Pa...      R
# 1        5  Illeana Douglas delivers a superb performance ...      R
# 2        6  Michael Douglas runs afoul of a treacherous su...      R
# 3        8  The year is 1942. As the Allies unite overseas...     PG
# 4       10  Some cast and crew from NBC's highly acclaimed...  PG-13
# ...    ...                                                ...    ...
# 1049  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1050  1997  The popular Saturday Night Live sketch was exp...     PG
# 1051  1998  Based on a novel by Richard Powell, when the l...      G
# ...
